# %% [markdown]
# # Automated DJ set

# %%
# Base Data Science snippet
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import time
from tqdm import tqdm_notebook

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("C:/git/music-analysis/")
import miles

# %% [markdown]
# # Some references

# %% [markdown]
# - https://towardsdatascience.com/finding-choruses-in-songs-with-python-a925165f94a8

# %% [markdown]
# # Playground

# %%
from miles.music import *

# %%
folder = "C:/users/talvesdacosta/Music/"
file = "Hans Zimmer - Interstellar (Gabriel Ananda Edit) [Free Download].mp3"
path = os.path.join(folder,file)

# %%
music = Music(path,load_fast=True)
# Out:
# ... Loaded 'C:/users/talvesdacosta/Music/Hans Zimmer - Interstellar (Gabriel Ananda Edit) [Free Download].mp3' file
# ... Computed spectrogram
# C:\Users\talvesdacosta\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\fftpack\basic.py:159: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x
# ... Estimated tempo: 123.05 beats per minute

# %%
music.compute_spectrogram()

# %%
music.spectrogram.shape
# Out:
# (128, 19408)

# %%
music.show_spectrogram()

# %%
import librosa

# %%
librosa.core.get_duration(y=music.waveform, sr=music.sampling_rate)
# Out:
# 450.6370068027211

# %%
19408 / 60
# Out:
# 323.46666666666664

# %%
music.spectrogram.shape
# Out:
# (128, 19408)

# %%
# 3. Run the default beat tracker
tempo, beat_frames = librosa.beat.beat_track(y=music.waveform, sr=music.sampling_rate)
# Out:
# C:\Users\talvesdacosta\AppData\Local\Continuum\anaconda3\lib\site-packages\scipy\fftpack\basic.py:159: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   z[index] = x

# %%
# Out:
# array([    8,    29,    51,    72,    93,   114,   135,   157,   178,
#          199,   220,   241,   262,   284,   305,   326,   347,   368,
#          390,   411,   432,   453,   474,   495,   517,   538,   559,
#          580,   601,   623,   644,   665,   686,   707,   728,   750,
#          771,   792,   813,   834,   856,   877,   898,   919,   940,
#          961,   983,  1004,  1025,  1046,  1067,  1088,  1110,  1131,
#         1152,  1173,  1194,  1216,  1237,  1258,  1279,  1300,  1321,
#         1343,  1364,  1385,  1406,  1427,  1449,  1470,  1491,  1512,
#         1533,  1554,  1576,  1597,  1618,  1639,  1660,  1682,  1703,
#         1724,  1745,  1766,  1787,  1809,  1830,  1851,  1872,  1893,
#         1915,  1936,  1957,  1978,  1999,  2020,  2042,  2063,  2084,
#         2105,  2126,  2148,  2169,  2190,  2211,  2232,  2253,  2275,
#         2296,  2317,  2338,  2359,  2381,  2402,  2423,  2444,  2465,
# ...
